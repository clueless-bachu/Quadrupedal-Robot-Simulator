# %%
from gym_unity.envs import UnityEnv
import numpy as np
# import tensorflow as tf

# %%
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.bench import Monitor
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
env_filename = r"C:\Users\Vasista\Desktop\quadrupedal\quadrupedal_env\Test 1"
env = UnityEnv(env_filename, worker_id=1, use_visual=False, no_graphics=True)

env = DummyVecEnv([lambda: env for i in range(4)])
model = PPO2(MlpPolicy, env, verbose=1,n_steps=256)
model.load(r"C:\Users\Vasista\Desktop\quadrupedal\weights\test3")
model.learn(total_timesteps=9000000)
model.save(r"C:\Users\Vasista\Desktop\quadrupedal\weights\test3")

# %%
env_filename = r"C:\Users\Vasista\Desktop\quadrupedal\quadrupedal_env\Test 1"
env = UnityEnv(env_filename, worker_id=1, use_visual=False, no_graphics=False)

env = DummyVecEnv([lambda: env])
model = PPO2(MlpPolicy, env, verbose=1)
model.load(r"C:\Users\Vasista\Desktop\quadrupedal\weights\test3")

obs = env.reset()
while(1):
    actions = model.predict(obs)
    obs, reward, done,_ = env.step(actions)
    print(reward)
# Out:
# INFO:mlagents.envs:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of Training Brains : 1
#         Reset Parameters :
#
# Unity brain name: RobotBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space size (per agent): 32
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): [12]
#         Vector Action descriptions: , , , , , , , , , , ,
# INFO:gym_unity:1 agents within environment.
# WARNING:tensorflow:From C:\Users\Vasista\Anaconda3\envs\rl\lib\site-packages\stable_baselines\common\tf_util.py:57: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Vasista\Anaconda3\envs\rl\lib\site-packages\stable_baselines\common\tf_util.py:66: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...
